# %%
import pandas as pd
import numpy as np

# Load your training data
df = pd.read_csv('data/training_data.csv')

# Explore the data
print(df.head())
print(df.info())
print(df.describe())
print(df.isnull().sum())
print(df.shape)
print(df.shape)
print(df.columns)
print(df.dtypes)
# Out:
#    activeModeRatio  questionsGenerated  debatesParticipated  \
# 0         0.823440           34.713233            10.188019
# 1         0.593845           38.654515            16.603998
# 2         0.312450            2.924004             3.738010
# 3         0.763661           24.020933            18.694042
# 4         0.350803            0.000000             0.000000
#
#    reflectiveModeRatio  reflectionsWritten  journalEntries  aiAskModeRatio  \
# 0             0.178442            8.988995        2.035555        0.643128
# 1             0.369584            7.750609        3.698369        0.756004
# 2             0.772438           15.122987       15.686163        0.298164
# 3             0.218481            0.000000        0.000000        0.741738
# 4             0.642883           23.941508       14.788122        0.247004
#
#    aiResearchModeRatio  sensingModeRatio  simulationsCompleted  ...  \
# 0             0.247672          0.197177              6.989557  ...
# ...
